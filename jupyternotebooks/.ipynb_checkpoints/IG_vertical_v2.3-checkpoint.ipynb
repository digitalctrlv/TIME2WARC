# %% [markdown]
# # Integrated Gradients - Vertical analysis of model v2.3

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>WARNING: Running the following cells will lead to severe data loss</b>. The datasets used for this analysis are protected property of the KB National Library in the Netherlands. Therefore, paths to the user's annotations of the application are provided if one would like to test the analysis by themselves.
#
# However, <b> if you are interested in a deep dive of the XAI analysis of this project, do NOT run the following cells. </b>
# </div>

# %% [markdown]
# ## Confusion matrix as a reference for inspecting misclassifications

# %% [markdown]
# ![](img/confusion_matrix.v2.3_optimal_weights.png)

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from transformers_interpret import SequenceClassificationExplainer
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model_v2_3_name = "./models/v2_3_optimal_weights_fold1"
model_v2_3 = AutoModelForSequenceClassification.from_pretrained(model_v2_3_name)
model_v2_3.eval()

tokenizer_v2_3 = AutoTokenizer.from_pretrained("roberta-base")

# Make sure to use the correct dataset for each model
# For privacy reasons, I am not allowed to share the original dataset analyzed here.
# This path allows you to use it for your personal annotated websites.
df_13 = pd.read_json(r".\output\websites_annotated.jsonl", lines=True)

label_encoder = LabelEncoder()
df_13['label'] = label_encoder.fit_transform(df_13['period_bucket'])
# Out:
# Loading weights: 100%|█████████████████████████████████████████████████████████████| 201/201 [00:00<00:00, 9397.56it/s]

# %%
# After a few test runs some generators still showed,  but that is probably due to varying notations of e.g. 'FrontPage.Editor'

import sys
sys.path.append("./script_training")
from labeling_function import SignalExtractor

# Hard-coding the masking, already defined in the model algorithm but just to be sure.
def mask_payload(payload):
    if not isinstance(payload, str):
        return ""

    for signal_name, pattern in SignalExtractor.regex_patterns.items():
        payload = pattern.sub("", payload)
    return payload

# %%
# Testing the masking
subset = df_13[df_13['label'] == 0]
subset_reset = subset.reset_index(drop=True)
samples = []
for idx, row in subset[10:15].iterrows():
    subset_reset['payload'] = mask_payload(row['payload'])
    samples.append({
        # 'url': subset_reset.iloc[idx].get('url', 'unknown'),
        # 'payload_preview': subset_reset.iloc[idx]['payload'][:500],
        'idx': idx
    })

print(samples)
# Out:
# [{'idx': 23}, {'idx': 27}, {'idx': 31}, {'idx': 34}, {'idx': 40}]

# %% [markdown]
# ### 3.1 Targeting the misclassifications cases

# %%
from tqdm import tqdm

def missclassifications(model, tokenizer, df, true_label_idx, miss_label_idx, max_search=200):
    id2label = {0: "19971999", 1: "20002002", 2: "20032006", 3: "20072010"}
    
    true_str = id2label.get(true_label_idx)
    miss_str = id2label.get(miss_label_idx)

    # print("Searching for misclassifications...")

    subset = df[df['label'] == true_label_idx]

    count = 0

    subset_reset = subset.reset_index(drop=True)
    samples = []
    for idx, row in tqdm(subset_reset.iterrows(), total=len(subset_reset), desc="Calculating wrong predictions"):
        row['payload'] = mask_payload(row['payload'])
        
        if idx > max_search:
            print("Reached limit without finding more")
            break
            
        inputs = tokenizer(row['payload'], return_tensors="pt", truncation=True, max_length=512).to(model.device)

        # print(f"Test: {row['payload'][:200]}")
        
        with torch.no_grad():
            outputs = model(**inputs)
            
        predicted_idx = outputs.logits.argmax().item()

        # Check if this specific instance hits the error group
        if predicted_idx == miss_label_idx:
            samples.append({
                'url': subset_reset.iloc[idx].get('url', 'unknown'),
                # 'idx': idx,
                'payload': row['payload'],
                'true_label' : true_str,
                'pred_label' : id2label.get(predicted_idx)
            })

            if len(samples) >=3:
                break
    
    return samples

# %%
# We will load them again in the case studies below
# conf_97_03 = missclassifications(model_v2_3, tokenizer_v2_3, df_13, 0, 2)
# conf_97_07 = missclassifications(model_v2_3, tokenizer_v2_3, df_13, 0, 3)
# conf_03_97 = missclassifications(model_v2_3, tokenizer_v2_3, df_13, 2, 0)

# %%
def test(subset):
    item = subset[0]
    warc_payload = item['payload'] 
    url = item['url']
    return (warc_payload, 
            url, 
            print("--- Top Positive Tokens ---"), 
            print("=== Top Positive Tokens ==="))

print(test(conf_97_03))
# Out:
# --- Top Positive Tokens ---
# === Top Positive Tokens ===
# ...

# %% [markdown]
# ### 3.2 Visualizations and manual inspections

# %%
def visualization(model, tokenizer, subset, item_index=0):
    cls_explainer = SequenceClassificationExplainer(model, tokenizer)
    model.config.id2label = {0: "1997-1999", 1: "2000-2002", 2: "2003-2006", 3: "2007-2010"}

    item = subset[item_index]
    warc_payload = item['payload']
    attributions = cls_explainer(warc_payload)

    attr_df = pd.DataFrame(attributions, columns=['Token', 'Score'])

    list_top = 

    return (cls_explainer.visualize(true_class=item['true_label']), item['url'], print("=== Top Positive Tokens ==="), 
        print(attr_df.sort_values(by='Score', ascending=False).head(15)),
        print("\n=== Top Negative Tokens ==="),
        print(attr_df.sort_values(by='Score', ascending=True).head(15)))

# %% [markdown]
# #### 3.2.1 1997–1999 $\leftrightarrow$ 2003–2006
# Why does a 90s website look like the late 2000s to RoBERTa?

# %%
# Load the sample subset (n=3)
conf_97_03 = missclassifications(model_v2_3, tokenizer_v2_3, df_13, 0, 2)

# %%
# Visualize the attribution scores of the first sample (change item_index) 
visualization(model_v2_3, tokenizer_v2_3, conf_97_03, item_index=0)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>19971999</b></text></td><td><text style="padding-right:2em"><b>2003-2006 (0.41)</b></text></td><td><text style="padding-right:2em"><b>2003-2006</b></text></td><td><text style="paddi
# ...

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_97_03, item_index=1)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>19971999</b></text></td><td><text style="padding-right:2em"><b>2007-2010 (0.49)</b></text></td><td><text style="padding-right:2em"><b>2007-2010</b></text></td><td><text style="paddi
# ...

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_97_03, item_index=2)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>19971999</b></text></td><td><text style="padding-right:2em"><b>1997-1999 (0.36)</b></text></td><td><text style="padding-right:2em"><b>1997-1999</b></text></td><td><text style="paddi
# ...

# %% [markdown]
# #### 3.2.2. 1997–1999 $\rightarrow$ 2007–2010

# %%
# Load the sample subset (n=3)
conf_97_07 = missclassifications(model_v2_3, tokenizer_v2_3, df_13, 0, 3)
# Out:
# Calculating wrong predictions:   2%|▊                                                  | 7/455 [00:08<08:43,  1.17s/it]

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_97_07, item_index=0)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>19971999</b></text></td><td><text style="padding-right:2em"><b>2007-2010 (0.43)</b></text></td><td><text style="padding-right:2em"><b>2007-2010</b></text></td><td><text style="paddi
# ...

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_97_07, item_index=1)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>19971999</b></text></td><td><text style="padding-right:2em"><b>2003-2006 (0.35)</b></text></td><td><text style="padding-right:2em"><b>2003-2006</b></text></td><td><text style="paddi
# ...

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_97_07, item_index=2)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>19971999</b></text></td><td><text style="padding-right:2em"><b>2007-2010 (0.44)</b></text></td><td><text style="padding-right:2em"><b>2007-2010</b></text></td><td><text style="paddi
# ...

# %% [markdown]
# #### 3.2.3. 2003–2006 $\rightarrow$ 1997–1999 (41 instances)
# Why are mid-2000s pages leaking into the 90s bucket?

# %%
# Load the sample subset (n=3)
conf_03_97 = missclassifications(model_v2_3, tokenizer_v2_3, df_13, 2, 0)
# Out:
# Calculating wrong predictions:  11%|█████▋                                            | 14/123 [00:15<01:58,  1.08s/it]

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_03_97, item_index=0)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>20032006</b></text></td><td><text style="padding-right:2em"><b>1997-1999 (0.49)</b></text></td><td><text style="padding-right:2em"><b>1997-1999</b></text></td><td><text style="paddi
# ...

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_03_97, item_index=1)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>20032006</b></text></td><td><text style="padding-right:2em"><b>1997-1999 (0.47)</b></text></td><td><text style="padding-right:2em"><b>1997-1999</b></text></td><td><text style="paddi
# ...

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_03_97, item_index=2)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>20032006</b></text></td><td><text style="padding-right:2em"><b>1997-1999 (0.41)</b></text></td><td><text style="padding-right:2em"><b>1997-1999</b></text></td><td><text style="paddi
# ...

# %% [markdown]
# ### 3.3 Correct classifications

# %% [markdown]
# #### 3.3.1 2007–2010 $\leftrightarrow$ 2007-2010
# What constitutes a correct 2007-2010 prediction?

# %%
conf_07_07 = missclassifications(model_v2_3, tokenizer_v2_3, df_13, 3, 3)
# Out:
# Calculating wrong predictions:   3%|█▋                                                  | 3/92 [00:03<01:56,  1.31s/it]

# %%
visualization(model_v2_3, tokenizer_v2_3, conf_07_07, item_index=0)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>20072010</b></text></td><td><text style="padding-right:2em"><b>2007-2010 (0.71)</b></text></td><td><text style="padding-right:2em"><b>2007-2010</b></text></td><td><text style="paddi
# ...
